# %% [markdown]
# <a href="https://colab.research.google.com/github/cadu11/cadu11/blob/main/Tabuada_automatica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def gerar_tabuada(numero):
    print(f"\nTabuada do {numero}:\n")
    for i in range(1, 11):
        print(f"{numero} x {i:2} = {numero * i}")

while True:
    try:
        num = int(input("Digite um número para ver a tabuada (ou -1 para sair): "))
        if num == -1:
            print("Programa encerrado.")
            break
        gerar_tabuada(num)
    except ValueError:
        print("Por favor, digite um número inteiro válido.")
# Out:
# Digite um número para ver a tabuada (ou -1 para sair): 3
#
# Tabuada do 3:
#
# 3 x  1 = 3
# 3 x  2 = 6
# 3 x  3 = 9
# 3 x  4 = 12
# 3 x  5 = 15
# 3 x  6 = 18
# 3 x  7 = 21
# 3 x  8 = 24
# 3 x  9 = 27
# 3 x 10 = 30
# Digite um número para ver a tabuada (ou -1 para sair): -1
# Programa encerrado.
