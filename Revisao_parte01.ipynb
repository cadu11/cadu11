# %% [markdown]
# <a href="https://colab.research.google.com/github/cadu11/cadu11/blob/main/Revisao_parte01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite seu nome: ") # Obtem o nome do usuario
print("Ola, "+nome+ "!")
# Out:
# Digite seu nome: Carlos Eduardo
# Ola, Carlos Eduardo!

# %%
# Verificacao de senha simples

# Definir senha permitida
senha_permitida = "12345"

#Solicitar a senha do usuario
senha_usuario = input("Digite sua senha: ")

#Verificar se a senha esta correta
if senha_usuario == senha_permitida:
    print("Acesso permitido!")
else:
    print("Acesso negado!")
# Out:
# Digite sua senha: 12345
# Acesso permitido!

# %%
# Revisao sobre a utilizacao de listas

frutas = ["maça", "banana", "laranja"]
print(frutas[2])
# Out:
# laranja

# %%
# Organizacao dados de feedback de clientes
# Listas de feedbacks
feedbacks = ["Otimo servico!", "Produto chegou atrasado.", "Atendimento ruim."]
# Dicionario com informacoes de um cliente
cliente = {
    "nome": "João",
    "idade": 30,
    "feedback": feedbacks[0]
}

# imprimir feedbacks da lista

for feedback in feedbacks:
    print("-" +feedback)

# Imprimir informacoes do cliente
print("\nInformacoes do cliente:")
print("Nome:", cliente["nome"])
print("Idade:", cliente["idade"])
print("Feedback:", cliente["feedback"])
# Out:
# -Otimo servico!
# -Produto chegou atrasado.
# -Atendimento ruim.
#
# Informacoes do cliente:
# Nome: João
# Idade: 30
# Feedback: Otimo servico!

# %%
# Loop while

contador = 0
while contador < 5:
    print("Isso e a interacao numero", contador)
    contador += 1
# Out:
# Isso e a interacao numero 0
# Isso e a interacao numero 1
# Isso e a interacao numero 2
# Isso e a interacao numero 3
# Isso e a interacao numero 4

# %%
# Loop For

frutas = ["maça", "banana", "laranja"]
for fruta in frutas:
    print("Eu gosto de", fruta)
# Out:
# Eu gosto de maça
# Eu gosto de banana
# Eu gosto de laranja

# %%
# Suponha que voce tenha uma lista de notas de alunos e deseje calcular a media e classifica-los com base nessa media, veja uma possibilidade:

# Lista de notas dos alunos
notas = [85, 92, 78, 90, 88]

# calcula a media das notas
soma = 0
for nota in notas:
    soma += nota
media = soma / len(notas)

# OBS.: Utiliza append e utilizado em listas para add um elemento ao final da lista. Abaixo sera utilizado para add as notas dos alunos as listas de aprovados e alunos reprovados com base na comparacao com a media.
# Classifica os alunos com base na media
alunos_aprovados = []
alunos_reprovados = []

for nota in notas:
    if nota >= media:
        alunos_aprovados.append(nota)
    else:
        alunos_reprovados.append(nota)

# Imprime os resultados

print("Notas dos alunos:", nota)
print("Media das notas:", media)
print("Alunos aprovados:", alunos_aprovados)
print("Alunos reprovados:", alunos_reprovados)
# Out:
# Notas dos alunos: 88
# Media das notas: 86.6
# Alunos aprovados: [92, 90, 88]
# Alunos reprovados: [85, 78]

# %%
# Solicita o nome do usuário e o exibe
nome_usuario = input("Por favor, insira seu nome: ")
print(f"Olá, {nome_usuario}! Bem-vindo ao nosso sistema.")

# Solicita a idade do usuário e converte para inteiro
idade_usuario = int(input("Por favor, insira sua idade: "))

# Verifica se o usuário é maior de idade
if idade_usuario >= 18:
    print("Você é maior de idade.")
else:
    print("Você é menor de idade.")
# Out:
# Por favor, insira seu nome: CC
# Olá, CC! Bem-vindo ao nosso sistema.
# Por favor, insira sua idade: 19
# Você é maior de idade.

# %%
idade = 20
renda = 3000
if (idade > 18 and renda > 2000) or idade < 25:
    print("Aprovado")
# Out:
# Aprovado

# %%
total = 0
total = total + 1
print(total)
# Out:
# 1

# %%
idade = int(input("Digite sua idade: "))
if idade > 18:
    print("Maior de idade")
    print("Pode comprar bebida alcoolica")
    print("Pode dirigir")
    print("Pode votar")
else:
    print("Menor de idade")
    print("Nao pode comprar bebida alcoolica")
    print("Nao pode dirigir")
    print("Nao pode votar")
# Out:
# Digite sua idade: 13
# Menor de idade
# Nao pode comprar bebida alcoolica
# Nao pode dirigir
# Nao pode votar
