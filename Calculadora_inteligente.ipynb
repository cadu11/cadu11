# %% [markdown]
# <a href="https://colab.research.google.com/github/cadu11/cadu11/blob/main/Calculadora_inteligente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

print("=== CALCULADORA INTELIGENTE ===")
nome = input("Olá! Qual é o seu nome? ")

def menu():
    print(f"\nBem-vindo(a), {nome}!")
    print("Escolha uma operação:")
    print("1 - Adição (+)")
    print("2 - Subtração (-)")
    print("3 - Multiplicação (*)")
    print("4 - Divisão (/)")
    print("5 - Porcentagem (%)")
    print("6 - Raiz quadrada (√)")
    print("7 - Sair")

while True:
    menu()
    escolha = input("Digite o número da operação desejada: ")

    if escolha == "7":
        print(f"Tchau, {nome}! Até a próxima.")
        break

    if escolha in ["1", "2", "3", "4"]:
        try:
            num1 = float(input("Digite o primeiro número: "))
            num2 = float(input("Digite o segundo número: "))
        except ValueError:
            print("Entrada inválida. Por favor, digite números válidos.")
            continue

        if escolha == "1":
            print(f"Resultado: {num1} + {num2} = {num1 + num2}")
        elif escolha == "2":
            print(f"Resultado: {num1} - {num2} = {num1 - num2}")
        elif escolha == "3":
            print(f"Resultado: {num1} * {num2} = {num1 * num2}")
        elif escolha == "4":
            if num2 != 0:
                print(f"Resultado: {num1} / {num2} = {num1 / num2}")
            else:
                print("Erro: divisão por zero não é permitida.")

    elif escolha == "5":
        try:
            porcentagem = float(input("Digite a porcentagem que deseja calcular (ex: 10 para 10%): "))
            valor = float(input("Digite o valor base sobre o qual aplicar a porcentagem: "))
            resultado = porcentagem * valor / 100
            print(f"{porcentagem}% de {valor} é {resultado}")
        except ValueError:
            print("Entrada inválida. Por favor, digite números válidos.")

    elif escolha == "6":
        try:
            num = float(input("Digite o número para calcular a raiz quadrada: "))
            if num < 0:
                print("Erro: não é possível calcular a raiz de número negativo.")
            else:
                raiz = math.sqrt(num)
                print(f"Raiz quadrada de {num} é {raiz}")
        except ValueError:
            print("Entrada inválida. Por favor, digite um número válido.")
    else:
        print("Opção inválida. Escolha uma das opções do menu.")
# Out:
# === CALCULADORA INTELIGENTE ===
# Olá! Qual é o seu nome? Cadu
#
# Bem-vindo(a), Cadu!
# Escolha uma operação:
# 1 - Adição (+)
# 2 - Subtração (-)
# 3 - Multiplicação (*)
# 4 - Divisão (/)
# 5 - Porcentagem (%)
# 6 - Raiz quadrada (√)
# 7 - Sair
# Digite o número da operação desejada: 5
# Digite a porcentagem que deseja calcular (ex: 10 para 10%): 3
# Digite o valor base sobre o qual aplicar a porcentagem: 25
# 3.0% de 25.0 é 0.75
#
# Bem-vindo(a), Cadu!
# Escolha uma operação:
# 1 - Adição (+)
# 2 - Subtração (-)
# 3 - Multiplicação (*)
# 4 - Divisão (/)
# 5 - Porcentagem (%)
# 6 - Raiz quadrada (√)
# 7 - Sair
# Digite o número da operação desejada: 7
# Tchau, Cadu! Até a próxima.
