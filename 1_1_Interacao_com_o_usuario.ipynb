# %% [markdown]
# <a href="https://colab.research.google.com/github/cadu11/cadu11/blob/main/1_1_Interacao_com_o_usuario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Conhecendo o comando Print')

x = 8

print('x')
# Out:
# Conhecendo o comando Print
# x

# %%
y = 10
soma = x + y
print(soma)
# Out:
# 18

# %%
nome = 'Carlos Eduardo'
print(nome)
# Out:
# Carlos Eduardo

# %%
x = 5
print('O valor de x e', x)
# Out:
# O valor de x e 5

# %%
print('Eu,',nome, 'tirei',x, 'na prova de Python')
# Out:
# Eu, Carlos Eduardo tirei 5 na prova de Python

# %%
print('O valor de x e', x, 'e dobro e', x*2)
# Out:
# O valor de x e 5 e dobro e 10

# %%
y = 10; z = 20 + x - y

print('Declarar varias variaveis na mesma linha', y, z)
# Out:
# Declarar varias variaveis na mesma linha 10 15

# %%
x = 10
type(x)
print('x', type(x))

nome = 'Carlos Eduardo'
print('nome', type(nome))

num = '100'
num_convert = int(num)  #converter variavel
print('num', type(num))
print('num_conver', type(num_convert))

num_float = float(num)
print('num_float', num_float)
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_conver <class 'int'>
# num_float 100.0

# %%
nome = input("Digite o nome de usuario")   #Aguardar o usuariodigitar algo
print(nome)
# Out:
# Digite o nome de usuarioCarlos Eduardo
# Carlos Eduardo

# %%
valor = input('Digite a nota')
print(nome, 'sua nota foi', valor)
# Out:
# Digite a nota7,5
# Carlos Eduardo sua nota foi 7,5

# %%
valor = input('Digite o valor do produto: ')
print(valor)
# Out:
# Digite o valor do produto: 10
# 10

# %%
valor_convet = int(valor)
desconto = valor_convet + 5
print(desconto)
# Out:
# 15

# %%
desconto = int(valor) - 5
print(desconto)
# Out:
# 5
