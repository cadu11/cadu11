# %% [markdown]
# <a href="https://colab.research.google.com/github/cadu11/cadu11/blob/main/agenda_contatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

ARQUIVO = "/content/contatos.txt"

def carregar_contatos():
    contatos = []
    if os.path.exists(ARQUIVO):
        with open(ARQUIVO, "r", encoding="utf-8") as f:
            for linha in f:
                nome, telefone = linha.strip().split(";")
                contatos.append({"nome": nome, "telefone": telefone})
    return contatos

def salvar_contatos(contatos):
    with open(ARQUIVO, "w", encoding="utf-8") as f:
        for c in contatos:
            f.write(f"{c['nome']};{c['telefone']}\n")

def adicionar_contato(contatos):
    nome = input("Nome do contato: ")
    telefone = input("Telefone: ")
    contatos.append({"nome": nome, "telefone": telefone})
    salvar_contatos(contatos)
    print("✅ Contato adicionado com sucesso!")

def listar_contatos(contatos):
    print("\n📒 Lista de Contatos:")
    for i, c in enumerate(contatos, 1):
        print(f"{i}. {c['nome']} - {c['telefone']}")
    print()

def buscar_contato(contatos):
    termo = input("Buscar por nome: ")
    encontrados = [c for c in contatos if termo.lower() in c["nome"].lower()]
    if encontrados:
        print("\n🔎 Contatos encontrados:")
        for c in encontrados:
            print(f"{c['nome']} - {c['telefone']}")
    else:
        print("⚠️ Nenhum contato encontrado.")

def menu():
    contatos = carregar_contatos()
    while True:
        print("\n📱 AGENDA DE CONTATOS")
        print("1 - Adicionar contato")
        print("2 - Listar contatos")
        print("3 - Buscar contato")
        print("4 - Sair")
        opcao = input("Escolha uma opção: ")

        if opcao == "1":
            adicionar_contato(contatos)
        elif opcao == "2":
            listar_contatos(contatos)
        elif opcao == "3":
            buscar_contato(contatos)
        elif opcao == "4":
            print("👋 Até logo!")
            break
        else:
            print("❌ Opção inválida. Tente novamente.")

# Executar o menu
menu()
# Out:
# 📱 AGENDA DE CONTATOS
# 1 - Adicionar contato
# 2 - Listar contatos
# 3 - Buscar contato
# 4 - Sair
# Escolha uma opção: 1
# Nome do contato: Cadu
# Telefone: 31972236206
# ✅ Contato adicionado com sucesso!
#
# 📱 AGENDA DE CONTATOS
# 1 - Adicionar contato
# 2 - Listar contatos
# 3 - Buscar contato
# 4 - Sair
# Escolha uma opção: 4
# 👋 Até logo!

# %%
from google.colab import files
files.download("/content/contatos.txt")
