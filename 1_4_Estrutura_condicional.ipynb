# %% [markdown]
# <a href="https://colab.research.google.com/github/cadu11/cadu11/blob/main/1_4_Estrutura_condicional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#If
if 5 < 10:
  print('verdade')
# Out:
# verdade

# %%
#If or Else
num1 = 10
num2 = 20
if num1 < num2:
  print('num1 e maior que num2')
else:
  print('num2 e maior que num1')
# Out:
# num1 e maior que num2

# %%
num1 = 7
num2 = 4
num3 = 2
if num1 > num2 and num1 > num3:
  print('num1 e maior')
else:
  print('num1 nao e o maior')
# Out:
# num1 e maior

# %%
num1 = 10
num2 = 10
if num1 > num2:
  print('num1 e maior num2')
elif num1 < num2:
  print('num2 e maior que o num1')
else:
  print('num1 e igual ao num2')
# Out:
# num1 e igual ao num2
